# %% [markdown]
# # Decoder

# %%
import os
import glob
import cv2
import pandas as pd

# %%
def algo_A(image_list, result):
    count = 1
    print('ALGORITHM A')
    print('===========')
    for img in image_list:
        name = os.path.basename(img)
        name = name.split('.')[0]
        name = name.replace('_','')
        print(str(count) + ': ' + name)

        try:
            output = bwm1.extract(img, wm_shape=len_wm, mode='str')
            print('Decoded text: ' + output)
            if output == 'test':
                print('Result      : Pass')
                result.append('Pass')
            else:
                print('Result      : Fail')
                result.append('Fail')
        except:
            print('Decoded text: Error')
            print('Result      : Fail')
            result.append('Fail')
            pass
        
        count += 1
        print('-----')

    
def algo_B(image_list, result):
    count = 1
    print('ALGORITHM B')
    print('===========')
    for img in image_list:
        bgr = cv2.imread(img)
        name = os.path.basename(img)
        name = name.split('.')[0]
        name = name.replace('_','')
        print(str(count) + ': ' + name)

        try:
            decoder = WatermarkDecoder('bytes', 32)
            watermark = decoder.decode(bgr, 'dwtDct')
            output = watermark.decode('utf-8')
            print('Decoded text: ' + output)
            if output == 'test':
                print('Result      : Pass')
                result.append('Pass')
            else:
                print('Result      : Fail')
                result.append('Fail')
        except:
            print('Decoded text: Error')
            print('Result      : Fail')
            result.append('Fail')
            pass
        
        count += 1
        print('-----')
        
def algo_C(image_list, result):
    count = 1
    print('ALGORITHM C')
    print('===========')
    for img in image_list:
        bgr = cv2.imread(img)
        name = os.path.basename(img)
        name = name.split('.')[0]
        name = name.replace('_','')
        print(str(count) + ': ' + name)

        try:
            watermark = decoder.decode(bgr, 'dwtDctSvd')
            output = watermark.decode('utf-8')
            print('Decoded text: ' + output)
            if output == 'test':
                print('Result      : Pass')
                result.append('Pass')
            else:
                print('Result      : Fail')
                result.append('Fail')
        except:
            print('Decoded text: Error')
            print('Result      : Fail')
            result.append('Fail')
            pass
        
        count += 1
        print('-----')
        
def algo_D(image_list, result):
    count = 1
    print('ALGORITHM D')
    print('===========')
    for img in image_list:
        bgr = cv2.imread(img)
        name = os.path.basename(img)
        name = name.split('.')[0]
        name = name.replace('_','')
        print(str(count) + ': ' + name)

        try:
            decoder.loadModel()
            watermark = decoder.decode(bgr, 'rivaGan')
            output = watermark.decode('utf-8')
            print('Decoded text: ' + output)
            if output == 'test':
                print('Result      : Pass')
                result.append('Pass')
            else:
                print('Result      : Fail')
                result.append('Fail')
        except:
            print('Decoded text: Error')
            print('Result      : Fail')
            result.append('Fail')
            pass
        
        count += 1
        print('-----')

# %%
def Decoder(df):
    img_folder_list = os.listdir('out_att') # Check all folder in this dic

    #algo_list = ['Algo_A', 'Algo_B', 'Algo_C', 'Algo_D']
    for folder in img_folder_list: 
        algo_list = os.listdir('out_att/' + folder) # Check All algo folder

        for algo in algo_list: 
            imdir = 'out_att/' + folder + '/' + algo + '/'
            ext = ['png', 'jpg'] 
            result = []
            result.append(folder)
            files = []
            [files.extend(glob.glob(imdir + '*.' + e)) for e in ext]
            image_list = [(file) for file in files]

            if algo == 'Algo_A':
                result.append(algo)
                print('[Photo: ' + folder + ']') # Show photo
                algo_A(image_list, result)
                print(result)
                df_length = len(df)
                df.loc[df_length] = result
                
            elif algo == 'Algo_B':
                result.append(algo)
                print('[Photo: ' + folder + ']') # Show photo
                algo_B(image_list, result)            
                print(result)
                df_length = len(df)
                df.loc[df_length] = result
                
            elif algo == 'Algo_C':
                result.append(algo)
                print('[Photo: ' + folder + ']') # Show photo
                algo_C(image_list, result)  
                print(result)
                df_length = len(df)
                df.loc[df_length] = result
                
            elif algo == 'Algo_D':
                result.append(algo)
                print('[Photo: ' + folder + ']') # Show photo
                algo_D(image_list, result) 
                print(result)
                df_length = len(df)
                df.loc[df_length] = result

# %%
# Use this for JPG attack
# title = ['Photo', 'Algorithm', 'Averaging', 'BilateralFiltering', 'BrightnessDecrease',
#         'BrightnessIncrease', 'CropHorizontal', 'CropVertical', 'GaussianBlurring', 
#         'GaussianNoise', 'JPG', 'Masks', 'MedianBlurring', 'Poisson', 'Rotate', 'SaltPeper',
#         'ScaleDown', 'ScaleUp', 'SharpenFiltering', 'Speckle']

title = ['Photo', 'Algorithm', 'Averaging', 'BilateralFiltering', 'BrightnessDecrease',
        'BrightnessIncrease', 'CropHorizontal', 'CropVertical', 'GaussianBlurring', 
        'GaussianNoise', 'Masks', 'MedianBlurring', 'Poisson', 'Rotate', 'SaltPeper',
        'ScaleDown', 'ScaleUp', 'SharpenFiltering', 'Speckle']
df = pd.DataFrame(columns=title)

Decoder(df)
df.to_csv('csv/result.csv', index = False)
# Out:
# [Photo: MRI_1]
# ALGORITHM A
# ===========
# 1: 11blindaveraging
# Decoded text: test
# Result      : Pass
# -----
# 2: 11blindbilateralfiltering
# Decoded text: test
# Result      : Pass
# -----
# 3: 11blindbrightnessdecrease
# Decoded text: Error
# Result      : Fail
# -----
# 4: 11blindbrightnessincrease
# Decoded text: Error
# Result      : Fail
# -----
# 5: 11blindcrophorizontal
# Decoded text: test
# Result      : Pass
# -----
# 6: 11blindcropvertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: 11blindgaussianblurring
# Decoded text: test
# Result      : Pass
# -----
# 8: 11blindguassian
# Decoded text: 0
# Result      : Fail
# -----
# 9: 11blindmasks
# Decoded text: Error
# Result      : Fail
# -----
# 10: 11blindmedianblurring
# Decoded text: test
# Result      : Pass
# -----
# 11: 11blindpoisson
# Decoded text: test
# Result      : Pass
# -----
# 12: 11blindrotate
# Decoded text: Error
# Result      : Fail
# -----
# 13: 11blindsaltpepper
# Decoded text: test
# Result      : Pass
# -----
# 14: 11blindscaledown
# Decoded text: Error
# Result      : Fail
# -----
# 15: 11blindscaleup
# Decoded text: Error
# Result      : Fail
# -----
# 16: 11blindsharpenfiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: 11blindspeckle
# Decoded text: Error
# Result      : Fail
# -----
# ['MRI_1', 'Algo_A', 'Pass', 'Pass', 'Fail', 'Fail', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Fail']
# [Photo: MRI_1]
# ALGORITHM B
# ===========
# 1: 11wmaveraging
# Decoded text:
# Result      : Fail
# -----
# 2: 11wmbilateralfiltering
# Decoded text:
# Result      : Fail
# -----
# 3: 11wmcrophorizontal
# Decoded text: Error
# Result      : Fail
# -----
# 4: 11wmcropvertical
# Decoded text: gnf~
# Result      : Fail
# -----
# 5: 11wmdecreasebrightness
# Decoded text:
# Result      : Fail
# -----
# 6: 11wmdownscale
# Decoded text:
# Result      : Fail
# -----
# 7: 11wmgaussianblurring
# Decoded text:
# Result      : Fail
# -----
# 8: 11wmguassian
# Decoded text: Error
# Result      : Fail
# -----
# 9: 11wmincreasebrightness
# Decoded text:
# Result      : Fail
# -----
# 10: 11wmmasks
# Decoded text:
# Result      : Fail
# -----
# 11: 11wmmedianblurring
# Decoded text:
# Result      : Fail
# -----
# 12: 11wmpoisson
# Decoded text: test
# Result      : Pass
# -----
# 13: 11wmrotate
# Decoded text:
# Result      : Fail
# -----
# 14: 11wmsaltpepper
# Decoded text: test
# Result      : Pass
# -----
# 15: 11wmsharpenfiltering
# Decoded text: Error
# Result      : Fail
# -----
# 16: 11wmspeckle
# Decoded text: Error
# Result      : Fail
# -----
# 17: 11wmupscale
# Decoded text:
# Result      : Fail
# -----
# ['MRI_1', 'Algo_B', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail']
# [Photo: MRI_1]
# ALGORITHM C
# ===========
# 1: 11svdaveraging
# Decoded text: test
# Result      : Pass
# -----
# 2: 11svdbilateralfiltering
# Decoded text: pest
# Result      : Fail
# -----
# 3: 11svdcrophorizontal
# Decoded text: Error
# Result      : Fail
# -----
# 4: 11svdcropvertical
# Decoded text: Error
# Result      : Fail
# -----
# 5: 11svddecreasebrightness
# Decoded text: test
# Result      : Pass
# -----
# 6: 11svddownscale
# Decoded text:
# Result      : Fail
# -----
# 7: 11svdgaussianblurring
# Decoded text: test
# Result      : Pass
# -----
# 8: 11svdguassian
# Decoded text: Error
# Result      : Fail
# -----
# 9: 11svdincreasebrightness
# Decoded text: test
# Result      : Pass
# -----
# 10: 11svdmasks
# Decoded text: tect
# Result      : Fail
# -----
# 11: 11svdmedianblurring
# Decoded text: test
# Result      : Pass
# -----
# 12: 11svdpoisson
# Decoded text: test
# Result      : Pass
# -----
# 13: 11svdrotate
# Decoded text:
# Result      : Fail
# -----
# 14: 11svdsaltpepper
# Decoded text: test
# Result      : Pass
# -----
# 15: 11svdsharpenfiltering
# Decoded text: Error
# Result      : Fail
# -----
# 16: 11svdspeckle
# Decoded text: tes|
# Result      : Fail
# -----
# 17: 11svdupscale
# Decoded text:
# Result      : Fail
# -----
# ['MRI_1', 'Algo_C', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail']
# [Photo: MRI_1]
# ALGORITHM D
# ===========
# 1: 11rgaveraging
# Decoded text: test
# Result      : Pass
# -----
# 2: 11rgbilateralfiltering
# Decoded text: test
# Result      : Pass
# -----
# 3: 11rgcrophorizontal
# Decoded text: Error
# Result      : Fail
# -----
# 4: 11rgcropvertical
# Decoded text: test
# Result      : Pass
# -----
# 5: 11rgdecreasebrightness
# Decoded text: test
# Result      : Pass
# -----
# 6: 11rgdownscale
# Decoded text: test
# Result      : Pass
# -----
# 7: 11rggaussianblurring
# Decoded text: test
# Result      : Pass
# -----
# 8: 11rgguassian
# Decoded text: test
# Result      : Pass
# -----
# 9: 11rgincreasebrightness
# Decoded text: test
# Result      : Pass
# -----
# 10: 11rgmasks
# Decoded text: test
# Result      : Pass
# -----
# 11: 11rgmedianblurring
# Decoded text: test
# Result      : Pass
# -----
# 12: 11rgpoisson
# Decoded text: test
# Result      : Pass
# -----
# 13: 11rgrotate
# Decoded text: test
# Result      : Pass
# -----
# 14: 11rgsaltpepper
# Decoded text: tdst
# Result      : Fail
# -----
# 15: 11rgsharpenfiltering
# Decoded text: test
# Result      : Pass
# -----
# 16: 11rgspeckle
# Decoded text: test
# Result      : Pass
# -----
# 17: 11rgupscale
# Decoded text: test
# Result      : Pass
# -----
# ['MRI_1', 'Algo_D', 'Pass', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass']

# %%
df
# Out:
#    Photo Algorithm Averaging BilateralFiltering BrightnessDecrease  \
# 0  MRI_1    Algo_A      Pass               Pass               Fail
# 1  MRI_1    Algo_B      Fail               Fail               Fail
# 2  MRI_1    Algo_C      Pass               Fail               Fail
# 3  MRI_1    Algo_D      Pass               Pass               Fail
#
#   BrightnessIncrease CropHorizontal CropVertical GaussianBlurring  \
# 0               Fail           Pass         Fail             Pass
# 1               Fail           Fail         Fail             Fail
# 2               Fail           Pass         Fail             Pass
# 3               Pass           Pass         Pass             Pass
#
#   GaussianNoise Masks MedianBlurring Poisson Rotate SaltPeper ScaleDown  \
# 0          Fail  Fail           Pass    Pass   Fail      Pass      Fail
# 1          Fail  Fail           Fail    Fail   Pass      Fail      Pass
# 2          Fail  Pass           Fail    Pass   Pass      Fail      Pass
# 3          Pass  Pass           Pass    Pass   Pass      Pass      Fail
#
#   ScaleUp SharpenFiltering Speckle
# 0    Fail             Fail    Fail
# 1    Fail             Fail    Fail
# 2    Fail             Fail    Fail
# 3    Pass             Pass    Pass
