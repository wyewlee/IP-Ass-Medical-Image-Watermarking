# %% [markdown]
# # Decoder

# %%
import cv2
import os
from imwatermark import WatermarkEncoder
from blind_watermark import WaterMark
from skimage.util import random_noise
from imwatermark import WatermarkDecoder
import numpy as np
import random

# %%
import os
import glob
import cv2
import pandas as pd

# %%
def algo_A(image_list, result):
    count = 1
    print('ALGORITHM A')
    print('===========')
    for img in image_list:
        name = os.path.basename(img)
        name = name.split('.')[0]
        name = name.replace('_','')
        print(str(count) + ': ' + name)

        try:
            bwm1=WaterMark(password_img=1,password_wm=1)
            output = bwm1.extract(img, wm_shape=31, mode='str')
            print('Decoded text: ' + output)
            if output == 'zhen':
                print('Result      : Pass')
                result.append('Pass')
            else:
                print('Result      : Fail')
                result.append('Fail')
        except:
            print('Decoded text: Error')
            print('Result      : Fail')
            result.append('Fail')
            pass
        
        count += 1
        print('-----')

    
def algo_B(image_list, result):
    count = 1
    print('ALGORITHM B')
    print('===========')
    for img in image_list:
        bgr = cv2.imread(img)
        name = os.path.basename(img)
        name = name.split('.')[0]
        name = name.replace('_','')
        print(str(count) + ': ' + name)

        try:
            decoder = WatermarkDecoder('bytes', 32)
            watermark = decoder.decode(bgr, 'dwtDct')
            output = watermark.decode('utf-8')
            print('Decoded text: ' + output)
            if output == 'zhen':
                print('Result      : Pass')
                result.append('Pass')
            else:
                print('Result      : Fail')
                result.append('Fail')
        except:
            print('Decoded text: Error')
            print('Result      : Fail')
            result.append('Fail')
            pass
        
        count += 1
        print('-----')
        
def algo_C(image_list, result):
    count = 1
    print('ALGORITHM C')
    print('===========')
    for img in image_list:
        bgr = cv2.imread(img)
        name = os.path.basename(img)
        name = name.split('.')[0]
        name = name.replace('_','')
        print(str(count) + ': ' + name)

        try:
            decoder = WatermarkDecoder('bytes', 32)
            watermark = decoder.decode(bgr, 'dwtDctSvd')
            output = watermark.decode('utf-8')
            print('Decoded text: ' + output)
            if output == 'zhen':
                print('Result      : Pass')
                result.append('Pass')
            else:
                print('Result      : Fail')
                result.append('Fail')
        except:
            print('Decoded text: Error')
            print('Result      : Fail')
            result.append('Fail')
            pass
        
        count += 1
        print('-----')
        
def algo_D(image_list, result):
    count = 1
    print('ALGORITHM D')
    print('===========')
    for img in image_list:
        bgr = cv2.imread(img)
        name = os.path.basename(img)
        name = name.split('.')[0]
        name = name.replace('_','')
        print(str(count) + ': ' + name)

        try:
            decoder.loadModel()
            watermark = decoder.decode(bgr, 'rivaGan')
            output = watermark.decode('utf-8')
            print('Decoded text: ' + output)
            if output == 'zhen':
                print('Result      : Pass')
                result.append('Pass')
            else:
                print('Result      : Fail')
                result.append('Fail')
        except:
            print('Decoded text: Error')
            print('Result      : Fail')
            result.append('Fail')
            pass
        
        count += 1
        print('-----')

# %%
def Decoder(df):
    img_folder_list = os.listdir('out_att') # Check all folder in this dic

    for folder in img_folder_list: 
        algo_list = os.listdir(os.path.join('out_att',folder)) # Check All algo folder
        
        for algo in algo_list: 
            imdir = os.path.join('out_att',folder,algo,'')
            ext = ['png', 'jpg'] 
            result = []
            result.append(folder)
            files = []
            [files.extend(glob.glob(imdir + '*.' + e)) for e in ext]
            image_list = [(file) for file in files]

            if algo == 'algo_a':
                result.append(algo)
                print('[Photo: ' + folder + ']') # Show photo
                algo_A(image_list, result)
                print(result)
                df_length = len(df)
                df.loc[df_length] = result
                
            elif algo == 'algo_b':
                result.append(algo)
                print('[Photo: ' + folder + ']') # Show photo
                algo_B(image_list, result)            
                print(result)
                df_length = len(df)
                df.loc[df_length] = result
                
            elif algo == 'algo_c':
                result.append(algo)
                print('[Photo: ' + folder + ']') # Show photo
                algo_C(image_list, result)  
                print(result)
                df_length = len(df)
                df.loc[df_length] = result
                
            elif algo == 'algo_d':
                result.append(algo)
                print('[Photo: ' + folder + ']') # Show photo
                algo_D(image_list, result) 
                print(result)
                df_length = len(df)
                df.loc[df_length] = result

# %%
# Use this for JPG attack
title = ['Photo', 'Algorithm', 'Averaging', 'BilateralFiltering', 'BrightnessDecrease',
        'BrightnessIncrease', 'CropHorizontal', 'CropVertical', 'GaussianBlurring', 
        'GaussianNoise', 'JPG', 'Masks', 'MedianBlurring', 'Poisson', 'Rotate', 'SaltPeper',
        'ScaleDown', 'ScaleUp', 'SharpenFiltering', 'Speckle']

df = pd.DataFrame(columns=title)

Decoder(df)

output_path=os.path.join('csv','result.csv')

df.to_csv(output_path, index = False)
# Out:
# [Photo: MRI_A]
# ALGORITHM A
# ===========
# 1: Averaging
# Decoded text: zhen
# Result      : Pass
# -----
# 2: BilateralFiltering
# Decoded text: zhen
# Result      : Pass
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 8: GaussianNoise
# Decoded text: @@
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text: Error
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text: Error
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text: Error
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text: zhen
# Result      : Pass
# -----
# ['MRI_A', 'algo_a', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Pass']
# [Photo: MRI_A]
# ALGORITHM B
# ===========
# 1: Averaging
# Decoded text:
# Result      : Fail
# -----
# 2: BilateralFiltering
# Decoded text:
# Result      : Fail
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text:
# Result      : Fail
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text:
# Result      : Fail
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text:
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text:
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text:
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text:
# Result      : Fail
# -----
# ['MRI_A', 'algo_b', 'Fail', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Fail']
# [Photo: MRI_A]
# ALGORITHM C
# ===========
# 1: Averaging
# Decoded text: zhen
# Result      : Pass
# -----
# 2: BilateralFiltering
# Decoded text: zhan
# Result      : Fail
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text:
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text: TP
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text:
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text: zhen
# Result      : Pass
# -----
# ['MRI_A', 'algo_c', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Pass']
# [Photo: MRI_A]
# ALGORITHM D
# ===========
# 1: Averaging
# Decoded text: Error
# Result      : Fail
# -----
# 2: BilateralFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 3: BrightnessDecrease
# Decoded text: Error
# Result      : Fail
# -----
# 4: BrightnesIncrease
# Decoded text: Error
# Result      : Fail
# -----
# 5: CropHorizontal
# Decoded text: Error
# Result      : Fail
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: Error
# Result      : Fail
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: Error
# Result      : Fail
# -----
# 10: MedianBlurring
# Decoded text: Error
# Result      : Fail
# -----
# 11: Poisson
# Decoded text: Error
# Result      : Fail
# -----
# 12: Rotate
# Decoded text: Error
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: Error
# Result      : Fail
# -----
# 14: ScaleDown
# Decoded text: Error
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text: Error
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: Error
# Result      : Fail
# -----
# 18: JPG
# Decoded text: Error
# Result      : Fail
# -----
# ['MRI_A', 'algo_d', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail']
# [Photo: MRI_B]
# ALGORITHM A
# ===========
# 1: Averaging
# Decoded text: zhen
# Result      : Pass
# -----
# 2: BilateralFiltering
# Decoded text: zhen
# Result      : Pass
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: }b&?
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 8: GaussianNoise
# Decoded text: 0
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text: Error
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text: Error
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text: Error
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text: zhen
# Result      : Pass
# -----
# ['MRI_B', 'algo_a', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Pass']
# [Photo: MRI_B]
# ALGORITHM B
# ===========
# 1: Averaging
# Decoded text:
# Result      : Fail
# -----
# 2: BilateralFiltering
# Decoded text:
# Result      : Fail
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text:
# Result      : Fail
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text:
# Result      : Fail
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text:
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text:
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text:
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text:
# Result      : Fail
# -----
# ['MRI_B', 'algo_b', 'Fail', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Fail']
# [Photo: MRI_B]
# ALGORITHM C
# ===========
# 1: Averaging
# Decoded text: zhen
# Result      : Pass
# -----
# 2: BilateralFiltering
# Decoded text: zhen
# Result      : Pass
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text:
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text:
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text:
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text: zhen
# Result      : Pass
# -----
# ['MRI_B', 'algo_c', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Pass']
# [Photo: MRI_B]
# ALGORITHM D
# ===========
# 1: Averaging
# Decoded text: Error
# Result      : Fail
# -----
# 2: BilateralFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 3: BrightnessDecrease
# Decoded text: Error
# Result      : Fail
# -----
# 4: BrightnesIncrease
# Decoded text: Error
# Result      : Fail
# -----
# 5: CropHorizontal
# Decoded text: Error
# Result      : Fail
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: Error
# Result      : Fail
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: Error
# Result      : Fail
# -----
# 10: MedianBlurring
# Decoded text: Error
# Result      : Fail
# -----
# 11: Poisson
# Decoded text: Error
# Result      : Fail
# -----
# 12: Rotate
# Decoded text: Error
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: Error
# Result      : Fail
# -----
# 14: ScaleDown
# Decoded text: Error
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text: Error
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: Error
# Result      : Fail
# -----
# 18: JPG
# Decoded text: Error
# Result      : Fail
# -----
# ['MRI_B', 'algo_d', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail']
# [Photo: MRI_C]
# ALGORITHM A
# ===========
# 1: Averaging
# Decoded text: zhen
# Result      : Pass
# -----
# 2: BilateralFiltering
# Decoded text: zhen
# Result      : Pass
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: >{\/
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text: Error
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text: Error
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text: Error
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text: zhen
# Result      : Pass
# -----
# ['MRI_C', 'algo_a', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Pass']
# [Photo: MRI_C]
# ALGORITHM B
# ===========
# 1: Averaging
# Decoded text:
# Result      : Fail
# -----
# 2: BilateralFiltering
# Decoded text:
# Result      : Fail
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text:
# Result      : Fail
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text:
# Result      : Fail
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text:
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text:
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text:
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text:
# Result      : Fail
# -----
# ['MRI_C', 'algo_b', 'Fail', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Fail']
# [Photo: MRI_C]
# ALGORITHM C
# ===========
# 1: Averaging
# Decoded text: zhen
# Result      : Pass
# -----
# 2: BilateralFiltering
# Decoded text: zhen
# Result      : Pass
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text:
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text:
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text: Error
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text: zhen
# Result      : Pass
# -----
# ['MRI_C', 'algo_c', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Pass']
# [Photo: MRI_C]
# ALGORITHM D
# ===========
# 1: Averaging
# Decoded text: Error
# Result      : Fail
# -----
# 2: BilateralFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 3: BrightnessDecrease
# Decoded text: Error
# Result      : Fail
# -----
# 4: BrightnesIncrease
# Decoded text: Error
# Result      : Fail
# -----
# 5: CropHorizontal
# Decoded text: Error
# Result      : Fail
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: Error
# Result      : Fail
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: Error
# Result      : Fail
# -----
# 10: MedianBlurring
# Decoded text: Error
# Result      : Fail
# -----
# 11: Poisson
# Decoded text: Error
# Result      : Fail
# -----
# 12: Rotate
# Decoded text: Error
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: Error
# Result      : Fail
# -----
# 14: ScaleDown
# Decoded text: Error
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text: Error
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: Error
# Result      : Fail
# -----
# 18: JPG
# Decoded text: Error
# Result      : Fail
# -----
# ['MRI_C', 'algo_d', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail']
# [Photo: MRI_D]
# ALGORITHM A
# ===========
# 1: Averaging
# Decoded text: zhen
# Result      : Pass
# -----
# 2: BilateralFiltering
# Decoded text: zhen
# Result      : Pass
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 8: GaussianNoise
# Decoded text:
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text: @
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text: Error
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text: Error
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text: zhen
# Result      : Pass
# -----
# ['MRI_D', 'algo_a', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Pass']
# [Photo: MRI_D]
# ALGORITHM B
# ===========
# 1: Averaging
# Decoded text:
# Result      : Fail
# -----
# 2: BilateralFiltering
# Decoded text:
# Result      : Fail
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text:
# Result      : Fail
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text:
# Result      : Fail
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text:
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text:
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text:
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text:
# Result      : Fail
# -----
# ['MRI_D', 'algo_b', 'Fail', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Fail']
# [Photo: MRI_D]
# ALGORITHM C
# ===========
# 1: Averaging
# Decoded text: zhen
# Result      : Pass
# -----
# 2: BilateralFiltering
# Decoded text: zhen
# Result      : Pass
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 8: GaussianNoise
# Decoded text: jiUf
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text:
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text:
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text:
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text: zhen
# Result      : Pass
# -----
# ['MRI_D', 'algo_c', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Pass']
# [Photo: MRI_D]
# ALGORITHM D
# ===========
# 1: Averaging
# Decoded text: Error
# Result      : Fail
# -----
# 2: BilateralFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 3: BrightnessDecrease
# Decoded text: Error
# Result      : Fail
# -----
# 4: BrightnesIncrease
# Decoded text: Error
# Result      : Fail
# -----
# 5: CropHorizontal
# Decoded text: Error
# Result      : Fail
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: Error
# Result      : Fail
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: Error
# Result      : Fail
# -----
# 10: MedianBlurring
# Decoded text: Error
# Result      : Fail
# -----
# 11: Poisson
# Decoded text: Error
# Result      : Fail
# -----
# 12: Rotate
# Decoded text: Error
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: Error
# Result      : Fail
# -----
# 14: ScaleDown
# Decoded text: Error
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text: Error
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: Error
# Result      : Fail
# -----
# 18: JPG
# Decoded text: Error
# Result      : Fail
# -----
# ['MRI_D', 'algo_d', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail']
# [Photo: MRI_E]
# ALGORITHM A
# ===========
# 1: Averaging
# Decoded text: zhen
# Result      : Pass
# -----
# 2: BilateralFiltering
# Decoded text: zhen
# Result      : Pass
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 8: GaussianNoise
# Decoded text: @
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text: Error
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text: Error
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text: Error
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text: zhen
# Result      : Pass
# -----
# ['MRI_E', 'algo_a', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Pass']
# [Photo: MRI_E]
# ALGORITHM B
# ===========
# 1: Averaging
# Decoded text:
# Result      : Fail
# -----
# 2: BilateralFiltering
# Decoded text:
# Result      : Fail
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text:
# Result      : Fail
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text:
# Result      : Fail
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text:
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text:
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text:
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text:
# Result      : Fail
# -----
# ['MRI_E', 'algo_b', 'Fail', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Fail']
# [Photo: MRI_E]
# ALGORITHM C
# ===========
# 1: Averaging
# Decoded text: zhen
# Result      : Pass
# -----
# 2: BilateralFiltering
# Decoded text: z`dn
# Result      : Fail
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 8: GaussianNoise
# Decoded text: jh1>
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text:
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text:
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text: Error
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text: zhen
# Result      : Pass
# -----
# ['MRI_E', 'algo_c', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Pass']
# [Photo: MRI_E]
# ALGORITHM D
# ===========
# 1: Averaging
# Decoded text: Error
# Result      : Fail
# -----
# 2: BilateralFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 3: BrightnessDecrease
# Decoded text: Error
# Result      : Fail
# -----
# 4: BrightnesIncrease
# Decoded text: Error
# Result      : Fail
# -----
# 5: CropHorizontal
# Decoded text: Error
# Result      : Fail
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: Error
# Result      : Fail
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: Error
# Result      : Fail
# -----
# 10: MedianBlurring
# Decoded text: Error
# Result      : Fail
# -----
# 11: Poisson
# Decoded text: Error
# Result      : Fail
# -----
# 12: Rotate
# Decoded text: Error
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: Error
# Result      : Fail
# -----
# 14: ScaleDown
# Decoded text: Error
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text: Error
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: Error
# Result      : Fail
# -----
# 18: JPG
# Decoded text: Error
# Result      : Fail
# -----
# ['MRI_E', 'algo_d', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail']
# [Photo: MRI_F]
# ALGORITHM A
# ===========
# 1: Averaging
# Decoded text: zhen
# Result      : Pass
# -----
# 2: BilateralFiltering
# Decoded text: zhen
# Result      : Pass
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: z{D
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 8: GaussianNoise
# Decoded text: @
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text: Error
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text: Error
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text: Error
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text: zhen
# Result      : Pass
# -----
# ['MRI_F', 'algo_a', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Pass']
# [Photo: MRI_F]
# ALGORITHM B
# ===========
# 1: Averaging
# Decoded text:
# Result      : Fail
# -----
# 2: BilateralFiltering
# Decoded text:
# Result      : Fail
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text:
# Result      : Fail
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text:
# Result      : Fail
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text:
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text:
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text:
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text:
# Result      : Fail
# -----
# ['MRI_F', 'algo_b', 'Fail', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Fail']
# [Photo: MRI_F]
# ALGORITHM C
# ===========
# 1: Averaging
# Decoded text: zhen
# Result      : Pass
# -----
# 2: BilateralFiltering
# Decoded text: zhen
# Result      : Pass
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text:
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text:
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text:
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text: zhen
# Result      : Pass
# -----
# ['MRI_F', 'algo_c', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Pass']
# [Photo: MRI_F]
# ALGORITHM D
# ===========
# 1: Averaging
# Decoded text: Error
# Result      : Fail
# -----
# 2: BilateralFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 3: BrightnessDecrease
# Decoded text: Error
# Result      : Fail
# -----
# 4: BrightnesIncrease
# Decoded text: Error
# Result      : Fail
# -----
# 5: CropHorizontal
# Decoded text: Error
# Result      : Fail
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: Error
# Result      : Fail
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: Error
# Result      : Fail
# -----
# 10: MedianBlurring
# Decoded text: Error
# Result      : Fail
# -----
# 11: Poisson
# Decoded text: Error
# Result      : Fail
# -----
# 12: Rotate
# Decoded text: Error
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: Error
# Result      : Fail
# -----
# 14: ScaleDown
# Decoded text: Error
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text: Error
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: Error
# Result      : Fail
# -----
# 18: JPG
# Decoded text: Error
# Result      : Fail
# -----
# ['MRI_F', 'algo_d', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail']
# [Photo: MRI_G]
# ALGORITHM A
# ===========
# 1: Averaging
# Decoded text: zhen
# Result      : Pass
# -----
# 2: BilateralFiltering
# Decoded text: zhen
# Result      : Pass
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 8: GaussianNoise
# Decoded text:
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text: @
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text: Error
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text: Error
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text: zhen
# Result      : Pass
# -----
# ['MRI_G', 'algo_a', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Pass']
# [Photo: MRI_G]
# ALGORITHM B
# ===========
# 1: Averaging
# Decoded text:
# Result      : Fail
# -----
# 2: BilateralFiltering
# Decoded text:
# Result      : Fail
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text:
# Result      : Fail
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text:
# Result      : Fail
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text:
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text:
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text:
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text:
# Result      : Fail
# -----
# ['MRI_G', 'algo_b', 'Fail', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Fail']
# [Photo: MRI_G]
# ALGORITHM C
# ===========
# 1: Averaging
# Decoded text: zhen
# Result      : Pass
# -----
# 2: BilateralFiltering
# Decoded text: xhen
# Result      : Fail
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 8: GaussianNoise
# Decoded text: FL
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text:
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text: dddd
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text:
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text: zhen
# Result      : Pass
# -----
# ['MRI_G', 'algo_c', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Pass']
# [Photo: MRI_G]
# ALGORITHM D
# ===========
# 1: Averaging
# Decoded text: Error
# Result      : Fail
# -----
# 2: BilateralFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 3: BrightnessDecrease
# Decoded text: Error
# Result      : Fail
# -----
# 4: BrightnesIncrease
# Decoded text: Error
# Result      : Fail
# -----
# 5: CropHorizontal
# Decoded text: Error
# Result      : Fail
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: Error
# Result      : Fail
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: Error
# Result      : Fail
# -----
# 10: MedianBlurring
# Decoded text: Error
# Result      : Fail
# -----
# 11: Poisson
# Decoded text: Error
# Result      : Fail
# -----
# 12: Rotate
# Decoded text: Error
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: Error
# Result      : Fail
# -----
# 14: ScaleDown
# Decoded text: Error
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text: Error
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: Error
# Result      : Fail
# -----
# 18: JPG
# Decoded text: Error
# Result      : Fail
# -----
# ['MRI_G', 'algo_d', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail']
# [Photo: MRI_H]
# ALGORITHM A
# ===========
# 1: Averaging
# Decoded text: zhen
# Result      : Pass
# -----
# 2: BilateralFiltering
# Decoded text: zhen
# Result      : Pass
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 8: GaussianNoise
# Decoded text: @
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text: Error
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text: @C#x
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text: Error
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text: zhen
# Result      : Pass
# -----
# ['MRI_H', 'algo_a', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Pass']
# [Photo: MRI_H]
# ALGORITHM B
# ===========
# 1: Averaging
# Decoded text:
# Result      : Fail
# -----
# 2: BilateralFiltering
# Decoded text:
# Result      : Fail
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: ffff
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text:
# Result      : Fail
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text:
# Result      : Fail
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text:
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text:
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text:
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text:
# Result      : Fail
# -----
# ['MRI_H', 'algo_b', 'Fail', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Fail']
# [Photo: MRI_H]
# ALGORITHM C
# ===========
# 1: Averaging
# Decoded text: zhen
# Result      : Pass
# -----
# 2: BilateralFiltering
# Decoded text: xhdn
# Result      : Fail
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: ffff
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text:
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text: UUUU
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text: UUUU
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text: zhen
# Result      : Pass
# -----
# ['MRI_H', 'algo_c', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Pass']
# [Photo: MRI_H]
# ALGORITHM D
# ===========
# 1: Averaging
# Decoded text: Error
# Result      : Fail
# -----
# 2: BilateralFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 3: BrightnessDecrease
# Decoded text: Error
# Result      : Fail
# -----
# 4: BrightnesIncrease
# Decoded text: Error
# Result      : Fail
# -----
# 5: CropHorizontal
# Decoded text: Error
# Result      : Fail
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: Error
# Result      : Fail
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: Error
# Result      : Fail
# -----
# 10: MedianBlurring
# Decoded text: Error
# Result      : Fail
# -----
# 11: Poisson
# Decoded text: Error
# Result      : Fail
# -----
# 12: Rotate
# Decoded text: Error
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: Error
# Result      : Fail
# -----
# 14: ScaleDown
# Decoded text: Error
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text: Error
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: Error
# Result      : Fail
# -----
# 18: JPG
# Decoded text: Error
# Result      : Fail
# -----
# ['MRI_H', 'algo_d', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail']
# [Photo: MRI_I]
# ALGORITHM A
# ===========
# 1: Averaging
# Decoded text: zhen
# Result      : Pass
# -----
# 2: BilateralFiltering
# Decoded text: zhen
# Result      : Pass
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text: Error
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text: Error
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text: Error
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text: zhen
# Result      : Pass
# -----
# ['MRI_I', 'algo_a', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Pass']
# [Photo: MRI_I]
# ALGORITHM B
# ===========
# 1: Averaging
# Decoded text:
# Result      : Fail
# -----
# 2: BilateralFiltering
# Decoded text:
# Result      : Fail
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text:
# Result      : Fail
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text:
# Result      : Fail
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text:
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text:
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text:
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text:
# Result      : Fail
# -----
# ['MRI_I', 'algo_b', 'Fail', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Fail']
# [Photo: MRI_I]
# ALGORITHM C
# ===========
# 1: Averaging
# Decoded text: zhen
# Result      : Pass
# -----
# 2: BilateralFiltering
# Decoded text: z`dn
# Result      : Fail
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text:
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text:
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text: Error
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text: zhen
# Result      : Pass
# -----
# ['MRI_I', 'algo_c', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Pass']
# [Photo: MRI_I]
# ALGORITHM D
# ===========
# 1: Averaging
# Decoded text: Error
# Result      : Fail
# -----
# 2: BilateralFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 3: BrightnessDecrease
# Decoded text: Error
# Result      : Fail
# -----
# 4: BrightnesIncrease
# Decoded text: Error
# Result      : Fail
# -----
# 5: CropHorizontal
# Decoded text: Error
# Result      : Fail
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: Error
# Result      : Fail
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: Error
# Result      : Fail
# -----
# 10: MedianBlurring
# Decoded text: Error
# Result      : Fail
# -----
# 11: Poisson
# Decoded text: Error
# Result      : Fail
# -----
# 12: Rotate
# Decoded text: Error
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: Error
# Result      : Fail
# -----
# 14: ScaleDown
# Decoded text: Error
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text: Error
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: Error
# Result      : Fail
# -----
# 18: JPG
# Decoded text: Error
# Result      : Fail
# -----
# ['MRI_I', 'algo_d', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail']
# [Photo: MRI_J]
# ALGORITHM A
# ===========
# 1: Averaging
# Decoded text: zhen
# Result      : Pass
# -----
# 2: BilateralFiltering
# Decoded text: zhen
# Result      : Pass
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text: Error
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text: Error
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text: Error
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text: zhen
# Result      : Pass
# -----
# ['MRI_J', 'algo_a', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Pass']
# [Photo: MRI_J]
# ALGORITHM B
# ===========
# 1: Averaging
# Decoded text:
# Result      : Fail
# -----
# 2: BilateralFiltering
# Decoded text:
# Result      : Fail
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text:
# Result      : Fail
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text:
# Result      : Fail
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text:
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text:
# Result      : Fail
# -----
# 15: ScaleUp
# ...
# Result      : Fail
# -----
# 10: MedianBlurring
# Decoded text: Error
# Result      : Fail
# -----
# 11: Poisson
# Decoded text: Error
# Result      : Fail
# -----
# 12: Rotate
# Decoded text: Error
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: Error
# Result      : Fail
# -----
# 14: ScaleDown
# Decoded text: Error
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text: Error
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: Error
# Result      : Fail
# -----
# 18: JPG
# Decoded text: Error
# Result      : Fail
# -----
# ['MRI_Q', 'algo_d', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail']
# [Photo: MRI_R]
# ALGORITHM A
# ===========
# 1: Averaging
# Decoded text: zhen
# Result      : Pass
# -----
# 2: BilateralFiltering
# Decoded text: zhen
# Result      : Pass
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 8: GaussianNoise
# Decoded text:
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text: Error
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text: Error
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text: Error
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text: zhen
# Result      : Pass
# -----
# ['MRI_R', 'algo_a', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Pass']
# [Photo: MRI_R]
# ALGORITHM B
# ===========
# 1: Averaging
# Decoded text:
# Result      : Fail
# -----
# 2: BilateralFiltering
# Decoded text:
# Result      : Fail
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: zlrj
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text:
# Result      : Fail
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text:
# Result      : Fail
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text:
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text:
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text:
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text:
# Result      : Fail
# -----
# ['MRI_R', 'algo_b', 'Fail', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Fail']
# [Photo: MRI_R]
# ALGORITHM C
# ===========
# 1: Averaging
# Decoded text: zhen
# Result      : Pass
# -----
# 2: BilateralFiltering
# Decoded text: x``n
# Result      : Fail
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: zlzn
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 8: GaussianNoise
# Decoded text: H,In
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text:
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text: TTTT
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text:
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text: zhen
# Result      : Pass
# -----
# ['MRI_R', 'algo_c', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Pass']
# [Photo: MRI_R]
# ALGORITHM D
# ===========
# 1: Averaging
# Decoded text: Error
# Result      : Fail
# -----
# 2: BilateralFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 3: BrightnessDecrease
# Decoded text: Error
# Result      : Fail
# -----
# 4: BrightnesIncrease
# Decoded text: Error
# Result      : Fail
# -----
# 5: CropHorizontal
# Decoded text: Error
# Result      : Fail
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: Error
# Result      : Fail
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: Error
# Result      : Fail
# -----
# 10: MedianBlurring
# Decoded text: Error
# Result      : Fail
# -----
# 11: Poisson
# Decoded text: Error
# Result      : Fail
# -----
# 12: Rotate
# Decoded text: Error
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: Error
# Result      : Fail
# -----
# 14: ScaleDown
# Decoded text: Error
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text: Error
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: Error
# Result      : Fail
# -----
# 18: JPG
# Decoded text: Error
# Result      : Fail
# -----
# ['MRI_R', 'algo_d', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail']
# [Photo: MRI_S]
# ALGORITHM A
# ===========
# 1: Averaging
# Decoded text: zhen
# Result      : Pass
# -----
# 2: BilateralFiltering
# Decoded text: zhen
# Result      : Pass
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: ryb
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 8: GaussianNoise
# Decoded text: @
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text: Error
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text: Error
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text: Error
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhun
# Result      : Fail
# -----
# 18: JPG
# Decoded text: zhen
# Result      : Pass
# -----
# ['MRI_S', 'algo_a', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Fail', 'Pass']
# [Photo: MRI_S]
# ALGORITHM B
# ===========
# 1: Averaging
# Decoded text:
# Result      : Fail
# -----
# 2: BilateralFiltering
# Decoded text:
# Result      : Fail
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text:
# Result      : Fail
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text:
# Result      : Fail
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text:
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text:
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text:
# Result      : Fail
# -----
# ['MRI_S', 'algo_b', 'Fail', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Fail']
# [Photo: MRI_S]
# ALGORITHM C
# ===========
# 1: Averaging
# Decoded text: zhen
# Result      : Pass
# -----
# 2: BilateralFiltering
# Decoded text: x``n
# Result      : Fail
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 8: GaussianNoise
# Decoded text: ~hln
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text:
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text:
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text:
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text: zhen
# Result      : Pass
# -----
# ['MRI_S', 'algo_c', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Pass']
# [Photo: MRI_S]
# ALGORITHM D
# ===========
# 1: Averaging
# Decoded text: Error
# Result      : Fail
# -----
# 2: BilateralFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 3: BrightnessDecrease
# Decoded text: Error
# Result      : Fail
# -----
# 4: BrightnesIncrease
# Decoded text: Error
# Result      : Fail
# -----
# 5: CropHorizontal
# Decoded text: Error
# Result      : Fail
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: Error
# Result      : Fail
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: Error
# Result      : Fail
# -----
# 10: MedianBlurring
# Decoded text: Error
# Result      : Fail
# -----
# 11: Poisson
# Decoded text: Error
# Result      : Fail
# -----
# 12: Rotate
# Decoded text: Error
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: Error
# Result      : Fail
# -----
# 14: ScaleDown
# Decoded text: Error
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text: Error
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: Error
# Result      : Fail
# -----
# 18: JPG
# Decoded text: Error
# Result      : Fail
# -----
# ['MRI_S', 'algo_d', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail']
# [Photo: MRI_T]
# ALGORITHM A
# ===========
# 1: Averaging
# Decoded text: zhen
# Result      : Pass
# -----
# 2: BilateralFiltering
# Decoded text: zhen
# Result      : Pass
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text: Error
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text: Error
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text: Rᱜ
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text: zhen
# Result      : Pass
# -----
# ['MRI_T', 'algo_a', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Pass']
# [Photo: MRI_T]
# ALGORITHM B
# ===========
# 1: Averaging
# Decoded text:
# Result      : Fail
# -----
# 2: BilateralFiltering
# Decoded text:
# Result      : Fail
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: zhzh
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text:
# Result      : Fail
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text:
# Result      : Fail
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text:
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text:
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text:
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text:
# Result      : Fail
# -----
# ['MRI_T', 'algo_b', 'Fail', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Fail']
# [Photo: MRI_T]
# ALGORITHM C
# ===========
# 1: Averaging
# Decoded text: zhen
# Result      : Pass
# -----
# 2: BilateralFiltering
# Decoded text: zhen
# Result      : Pass
# -----
# 3: BrightnessDecrease
# Decoded text: zhen
# Result      : Pass
# -----
# 4: BrightnesIncrease
# Decoded text: zhen
# Result      : Pass
# -----
# 5: CropHorizontal
# Decoded text: zhen
# Result      : Pass
# -----
# 6: CropVertical
# Decoded text: zhzh
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 8: GaussianNoise
# Decoded text: Z`vN
# Result      : Fail
# -----
# 9: Masks
# Decoded text: zhen
# Result      : Pass
# -----
# 10: MedianBlurring
# Decoded text: zhen
# Result      : Pass
# -----
# 11: Poisson
# Decoded text: zhen
# Result      : Pass
# -----
# 12: Rotate
# Decoded text: G
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: zhen
# Result      : Pass
# -----
# 14: ScaleDown
# Decoded text: TTTT
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text:
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: zhen
# Result      : Pass
# -----
# 18: JPG
# Decoded text: zhen
# Result      : Pass
# -----
# ['MRI_T', 'algo_c', 'Pass', 'Pass', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Pass', 'Pass', 'Pass', 'Fail', 'Pass', 'Fail', 'Fail', 'Fail', 'Pass', 'Pass']
# [Photo: MRI_T]
# ALGORITHM D
# ===========
# 1: Averaging
# Decoded text: Error
# Result      : Fail
# -----
# 2: BilateralFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 3: BrightnessDecrease
# Decoded text: Error
# Result      : Fail
# -----
# 4: BrightnesIncrease
# Decoded text: Error
# Result      : Fail
# -----
# 5: CropHorizontal
# Decoded text: Error
# Result      : Fail
# -----
# 6: CropVertical
# Decoded text: Error
# Result      : Fail
# -----
# 7: GaussianBlurring
# Decoded text: Error
# Result      : Fail
# -----
# 8: GaussianNoise
# Decoded text: Error
# Result      : Fail
# -----
# 9: Masks
# Decoded text: Error
# Result      : Fail
# -----
# 10: MedianBlurring
# Decoded text: Error
# Result      : Fail
# -----
# 11: Poisson
# Decoded text: Error
# Result      : Fail
# -----
# 12: Rotate
# Decoded text: Error
# Result      : Fail
# -----
# 13: SaltPepper
# Decoded text: Error
# Result      : Fail
# -----
# 14: ScaleDown
# Decoded text: Error
# Result      : Fail
# -----
# 15: ScaleUp
# Decoded text: Error
# Result      : Fail
# -----
# 16: SharpenFiltering
# Decoded text: Error
# Result      : Fail
# -----
# 17: Speckle
# Decoded text: Error
# Result      : Fail
# -----
# 18: JPG
# Decoded text: Error
# Result      : Fail
# -----
# ['MRI_T', 'algo_d', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail', 'Fail']

# %%
df
# Out:
#     Photo Algorithm Averaging BilateralFiltering BrightnessDecrease  \
# 0   MRI_A    algo_a      Pass               Pass               Pass
# 1   MRI_A    algo_b      Fail               Fail               Pass
# 2   MRI_A    algo_c      Pass               Fail               Pass
# 3   MRI_A    algo_d      Fail               Fail               Fail
# 4   MRI_B    algo_a      Pass               Pass               Pass
# ..    ...       ...       ...                ...                ...
# 75  MRI_S    algo_d      Fail               Fail               Fail
# 76  MRI_T    algo_a      Pass               Pass               Pass
# 77  MRI_T    algo_b      Fail               Fail               Pass
# 78  MRI_T    algo_c      Pass               Pass               Pass
# 79  MRI_T    algo_d      Fail               Fail               Fail
#
#    BrightnessIncrease CropHorizontal CropVertical GaussianBlurring  \
# 0                Pass           Pass         Fail             Pass
# 1                Pass           Pass         Fail             Fail
# 2                Pass           Pass         Fail             Pass
# 3                Fail           Fail         Fail             Fail
# 4                Pass           Pass         Fail             Pass
# ..                ...            ...          ...              ...
# 75               Fail           Fail         Fail             Fail
# 76               Pass           Pass         Fail             Pass
# 77               Pass           Pass         Fail             Fail
# 78               Pass           Pass         Fail             Pass
# 79               Fail           Fail         Fail             Fail
#
#    GaussianNoise   JPG Masks MedianBlurring Poisson Rotate SaltPeper  \
# 0           Fail  Pass  Pass           Pass    Fail   Pass      Fail
# 1           Fail  Pass  Fail           Pass    Fail   Pass      Fail
# 2           Fail  Pass  Pass           Pass    Fail   Pass      Fail
# 3           Fail  Fail  Fail           Fail    Fail   Fail      Fail
# 4           Fail  Pass  Pass           Pass    Fail   Pass      Fail
# ..           ...   ...   ...            ...     ...    ...       ...
# 75          Fail  Fail  Fail           Fail    Fail   Fail      Fail
# 76          Fail  Pass  Pass           Pass    Fail   Pass      Fail
# 77          Fail  Pass  Fail           Pass    Fail   Pass      Fail
# 78          Fail  Pass  Pass           Pass    Fail   Pass      Fail
# 79          Fail  Fail  Fail           Fail    Fail   Fail      Fail
#
#    ScaleDown ScaleUp SharpenFiltering Speckle
# 0       Fail    Fail             Pass    Pass
# 1       Fail    Fail             Pass    Fail
# 2       Fail    Fail             Pass    Pass
# 3       Fail    Fail             Fail    Fail
# 4       Fail    Fail             Pass    Pass
# ..       ...     ...              ...     ...
# 75      Fail    Fail             Fail    Fail
# 76      Fail    Fail             Pass    Pass
# 77      Fail    Fail             Pass    Fail
# 78      Fail    Fail             Pass    Pass
# 79      Fail    Fail             Fail    Fail
#
# [80 rows x 20 columns]
